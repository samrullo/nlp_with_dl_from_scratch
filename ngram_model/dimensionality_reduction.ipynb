# %%
import numpy as np

N=1000
X = np.random.randn(N)
a = 0.3
b = 0.1
Y = a * X + b + 0.1 * np.random.randn(N)
Y_true=0.3 * X + 0.1

# %%
import pandas as pd

df=pd.DataFrame({"X":X,"Y":Y})
print(df.head())
# Out:
#           X         Y
# 0 -0.476119 -0.139461
# 1 -0.028832  0.290126
# 2 -1.634379 -0.419039
# 3 -0.191415  0.022696
# 4 -1.367309 -0.331215

# %%
import matplotlib.pyplot as plt

plt.scatter(X,Y,alpha=0.5)
plt.plot(X,Y_true,color="red")
plt.show()
