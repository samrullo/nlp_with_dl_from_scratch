# %%
import pathlib
import numpy as np
import re
from sklearn.utils.extmath import randomized_svd
from utils import tokenize, build_vocabulary, get_word_to_id_from_vocab, get_id_to_word, build_corpus, create_cooccurrence_matrix

# %%
datasets_folder=pathlib.Path(r"C:\Users\amrul\programming\deep_learning\dl_projects\nlp_with_dl_from_scratch\datasets")
ptb_filename="ptb.train.txt"
text = (datasets_folder/ptb_filename).read_text()

# %%
from utils import tokenize

words = tokenize(text,special_words=["<unk>"])
print(f"total of {len(words):,} words")
# Out:
# total of 937,128 words

# %%
from utils import build_vocabulary

vocab = build_vocabulary(words)
print(f"vocab has {len(vocab):,} words")
# Out:
# vocab has 9,654 words

# %%
word_to_id = get_word_to_id_from_vocab(list(vocab))
print(word_to_id)
# Out:
# {'searle': 0, 'beyond': 1, 'magnified': 2, 'serving': 3, 'bologna': 4, 'bold': 5, 'obliged': 6, 'heller': 7, 'trelleborg': 8, 'wire': 9, 'hitachi': 10, 'refinancing': 11, 'tire': 12, 'barrier': 13, 'champion': 14, 'writers': 15, 'equivalent': 16, 'passion': 17, 'preserve': 18, 'conglomerate': 19, 'employees': 20, 'fleischmann': 21, 'bottled': 22, '45': 23, 'laughing': 24, 'compiled': 25, 'catastrophe': 26, 'wednesday': 27, 'plastic': 28, 'somehow': 29, 'some': 30, 'procter': 31, 'police': 32, 'opera': 33, 'fema': 34, 'weighing': 35, 'tissue': 36, 'glass': 37, 'recommendations': 38, 'dusty': 39, 'suggests': 40, 'jailed': 41, 'co': 42, 'families': 43, 'can': 44, 'patience': 45, 'knowing': 46, 'trudeau': 47, 'roger': 48, 'discouraging': 49, 'focusing': 50, 'hunter': 51, 'suddenly': 52, 'protesters': 53, 'preference': 54, 'fans': 55, 'ms': 56, 'coke': 57, 'transformed': 58, 'reduces': 59, 'foundations': 60, 'influential': 61, 'conservative': 62, 'component': 63, 'concluding': 64, 'hud': 65, 'transactions': 66, 'triple': 67, 'tangible': 68, 'moments': 69, 'inflows': 70, 'commitments': 71, 'profitable': 72, 'jeffrey': 73, 'lsi': 74, 'flooded': 75, 'brewing': 76, 'performed': 77, 'jefferies': 78, 'broadcasting': 79, 'print': 80, 'rebates': 81, 'spotted': 82, 'grasp': 83, 'hooker': 84, 'two': 85, 'trying': 86, 'lighter': 87, 'use': 88, 'sits': 89, 'reviews': 90, 'practice': 91, 'amount': 92, 'gaf': 93, 'backed': 94, 'smoking': 95, 'merged': 96, 'views': 97, 'vermont': 98, 'sometimes': 99, 'serve': 100, 'reputation': 101, 'rockwell': 102, 'experimental': 103, 'illustrates': 104, 'harold': 105, 'packed': 106, 'dillon': 107, 'ex': 108, 'retrieve': 109, 'spoke': 110, 'archrival': 111, 'clark': 112, 'guy': 113, 'pipes': 114, 'opinion': 115, 'illusion': 116, 'march': 117, 'fraudulent': 118, 'independent': 119, 'vans': 120, 'walked': 121, 'arrange': 122, 'dialysis': 123, 'morale': 124, 'upham': 125, 'budget': 126, 'scope': 127, 'considerably': 128, 'manufacturers': 129, 'suggesting': 130, 'siemens': 131, 'repairs': 132, 'title': 133, 'slim': 134, 'impending': 135, 'soliciting': 136, 'firmed': 137, 'tacked': 138, 'netherlands': 139, 'denying': 140, 'poised': 141, 'broadcast': 142, 'stops': 143, 'bono': 144, 'conspiring': 145, 'seasonal': 146, 'soften': 147, 'awarded': 148, 'emerge': 149, 'pizza': 150, 'thi': 151, 'attributed': 152, 'atlantis': 153, 'coin': 154, 'douglas': 155, 'billed': 156, 'enforcers': 157, 'nuclear': 158, 'statutory': 159, 'eddie': 160, 'ignoring': 161, 'tracking': 162, 'sanford': 163, 'condemn': 164, 'blames': 165, 'avoided': 166, 'loyalty': 167, 'northwest': 168, 'rubbermaid': 169, 'choice': 170, 'envy': 171, 'tesoro': 172, 'charges': 173, 'gerrymandering': 174, 'turnaround': 175, 'universities': 176, 'predictions': 177, 'neil': 178, 'wives': 179, 'savings': 180, 'elsewhere': 181, 'eggs': 182, 'teachers': 183, 'week': 184, 'highlight': 185, 'secured': 186, 'proper': 187, 'nwa': 188, 'decided': 189, 'any': 190, 'boards': 191, 'final': 192, 'silicon': 193, 'regret': 194, 'meantime': 195, 'distributed': 196, 'described': 197, 'document': 198, 'difficult': 199, 'wore': 200, 'jerome': 201, 'skipper': 202, 'interview': 203, 'plummet': 204, 'meaningful': 205, 'toronto': 206, 'memphis': 207, 'matter': 208, 'kemper': 209, 'wachovia': 210, 'special': 211, 'spot': 212, 'merksamer': 213, 'split': 214, 'olympia': 215, 'marshall': 216, '58': 217, 'legg': 218, 'sorrell': 219, 'connaught': 220, 'memorandum': 221, 'striking': 222, 'walt': 223, 'permitting': 224, 'unfair': 225, 'had': 226, 'appealed': 227, 'plead': 228, 'ethiopia': 229, 'dramatically': 230, 'song': 231, 'june': 232, 'removed': 233, 'yielding': 234, 'pop': 235, 'anniversary': 236, 'modernize': 237, 'magnetic': 238, 'gathered': 239, 'pledge': 240, 'freshman': 241, 'handicapped': 242, 'bring': 243, 'painted': 244, 'halted': 245, 'sporting': 246, 'burmah': 247, 'wellcome': 248, 'tumultuous': 249, 'authorized': 250, 'surgery': 251, 'fee': 252, 'camp': 253, 'supervisors': 254,  ...

# %%
id_to_word=get_id_to_word(word_to_id)
print(id_to_word)
# Out:
# {0: 'searle', 1: 'beyond', 2: 'magnified', 3: 'serving', 4: 'bologna', 5: 'bold', 6: 'obliged', 7: 'heller', 8: 'trelleborg', 9: 'wire', 10: 'hitachi', 11: 'refinancing', 12: 'tire', 13: 'barrier', 14: 'champion', 15: 'writers', 16: 'equivalent', 17: 'passion', 18: 'preserve', 19: 'conglomerate', 20: 'employees', 21: 'fleischmann', 22: 'bottled', 23: '45', 24: 'laughing', 25: 'compiled', 26: 'catastrophe', 27: 'wednesday', 28: 'plastic', 29: 'somehow', 30: 'some', 31: 'procter', 32: 'police', 33: 'opera', 34: 'fema', 35: 'weighing', 36: 'tissue', 37: 'glass', 38: 'recommendations', 39: 'dusty', 40: 'suggests', 41: 'jailed', 42: 'co', 43: 'families', 44: 'can', 45: 'patience', 46: 'knowing', 47: 'trudeau', 48: 'roger', 49: 'discouraging', 50: 'focusing', 51: 'hunter', 52: 'suddenly', 53: 'protesters', 54: 'preference', 55: 'fans', 56: 'ms', 57: 'coke', 58: 'transformed', 59: 'reduces', 60: 'foundations', 61: 'influential', 62: 'conservative', 63: 'component', 64: 'concluding', 65: 'hud', 66: 'transactions', 67: 'triple', 68: 'tangible', 69: 'moments', 70: 'inflows', 71: 'commitments', 72: 'profitable', 73: 'jeffrey', 74: 'lsi', 75: 'flooded', 76: 'brewing', 77: 'performed', 78: 'jefferies', 79: 'broadcasting', 80: 'print', 81: 'rebates', 82: 'spotted', 83: 'grasp', 84: 'hooker', 85: 'two', 86: 'trying', 87: 'lighter', 88: 'use', 89: 'sits', 90: 'reviews', 91: 'practice', 92: 'amount', 93: 'gaf', 94: 'backed', 95: 'smoking', 96: 'merged', 97: 'views', 98: 'vermont', 99: 'sometimes', 100: 'serve', 101: 'reputation', 102: 'rockwell', 103: 'experimental', 104: 'illustrates', 105: 'harold', 106: 'packed', 107: 'dillon', 108: 'ex', 109: 'retrieve', 110: 'spoke', 111: 'archrival', 112: 'clark', 113: 'guy', 114: 'pipes', 115: 'opinion', 116: 'illusion', 117: 'march', 118: 'fraudulent', 119: 'independent', 120: 'vans', 121: 'walked', 122: 'arrange', 123: 'dialysis', 124: 'morale', 125: 'upham', 126: 'budget', 127: 'scope', 128: 'considerably', 129: 'manufacturers', 130: 'suggesting', 131: 'siemens', 132: 'repairs', 133: 'title', 134: 'slim', 135: 'impending', 136: 'soliciting', 137: 'firmed', 138: 'tacked', 139: 'netherlands', 140: 'denying', 141: 'poised', 142: 'broadcast', 143: 'stops', 144: 'bono', 145: 'conspiring', 146: 'seasonal', 147: 'soften', 148: 'awarded', 149: 'emerge', 150: 'pizza', 151: 'thi', 152: 'attributed', 153: 'atlantis', 154: 'coin', 155: 'douglas', 156: 'billed', 157: 'enforcers', 158: 'nuclear', 159: 'statutory', 160: 'eddie', 161: 'ignoring', 162: 'tracking', 163: 'sanford', 164: 'condemn', 165: 'blames', 166: 'avoided', 167: 'loyalty', 168: 'northwest', 169: 'rubbermaid', 170: 'choice', 171: 'envy', 172: 'tesoro', 173: 'charges', 174: 'gerrymandering', 175: 'turnaround', 176: 'universities', 177: 'predictions', 178: 'neil', 179: 'wives', 180: 'savings', 181: 'elsewhere', 182: 'eggs', 183: 'teachers', 184: 'week', 185: 'highlight', 186: 'secured', 187: 'proper', 188: 'nwa', 189: 'decided', 190: 'any', 191: 'boards', 192: 'final', 193: 'silicon', 194: 'regret', 195: 'meantime', 196: 'distributed', 197: 'described', 198: 'document', 199: 'difficult', 200: 'wore', 201: 'jerome', 202: 'skipper', 203: 'interview', 204: 'plummet', 205: 'meaningful', 206: 'toronto', 207: 'memphis', 208: 'matter', 209: 'kemper', 210: 'wachovia', 211: 'special', 212: 'spot', 213: 'merksamer', 214: 'split', 215: 'olympia', 216: 'marshall', 217: '58', 218: 'legg', 219: 'sorrell', 220: 'connaught', 221: 'memorandum', 222: 'striking', 223: 'walt', 224: 'permitting', 225: 'unfair', 226: 'had', 227: 'appealed', 228: 'plead', 229: 'ethiopia', 230: 'dramatically', 231: 'song', 232: 'june', 233: 'removed', 234: 'yielding', 235: 'pop', 236: 'anniversary', 237: 'modernize', 238: 'magnetic', 239: 'gathered', 240: 'pledge', 241: 'freshman', 242: 'handicapped', 243: 'bring', 244: 'painted', 245: 'halted', 246: 'sporting', 247: 'burmah', 248: 'wellcome', 249: 'tumultuous', 250: 'authorized', 251: 'surgery', 252: 'fee', 253: 'camp', 254: 'supervisors',  ...

# %%
corpus=build_corpus(words,word_to_id)
print(corpus[:100])
# Out:
# [3038, 7577, 2333, 6256, 4023, 4249, 5350, 2774, 5629, 5229, 7876, 7337, 6919, 1258, 9498, 7369, 8195, 3085, 4256, 3346, 4385, 7134, 4948, 7876, 5538, 2200, 3806, 462, 1237, 9490, 9273, 2131, 1645, 3358, 8447, 329, 626, 1009, 8464, 1873, 8986, 5474, 6314, 9273, 7951, 6314, 9490, 7453, 7661, 8490, 9490, 7192, 6314, 6341, 6314, 329, 6786, 5182, 6782, 3479, 9490, 9273, 2131, 1645, 1119, 7647, 7661, 8490, 4034, 2297, 7338, 6626, 8807, 4366, 8464, 1873, 8986, 8490, 928, 2025, 5997, 19, 8464, 4649, 8490, 7008, 905, 4924, 6096, 3250, 1019, 8710, 7841, 2019, 4396, 8464, 960, 3092, 8490, 4411]

# %%
C = create_cooccurrence_matrix(corpus,window_size=1,vocab_size=len(vocab))
print(f"cooccurrence shape :  {C.shape}")
# Out:
# cooccurrence shape :  (9654, 9654)

# %%
from utils import build_ppmi

ppmi = build_ppmi(C)

print(f"ppmi shape : {ppmi.shape}")
# Out:
# PPMI building: 100%|██████████| 93199716/93199716 [04:43<00:00, 328724.64it/s]
# ppmi shape : (9654, 9654)

# %%
U,S,V = randomized_svd(ppmi,n_components=100, n_iter= 5, random_state=None)

# %%
def cosine_similarity(u,v):
    return u@v/(np.linalg.norm(u)*np.linalg.norm(v))

# %%
print(f"similarity between car and drive : {cosine_similarity(U[word_to_id['car']],U[word_to_id['drive']])}")
print(f"similarity between car and the : {cosine_similarity(U[word_to_id['car']],U[word_to_id['the']])}")
print(f"similarity between car and street : {cosine_similarity(U[word_to_id['car']],U[word_to_id['street']])}")
print(f"similarity between man and woman : {cosine_similarity(U[word_to_id['man']],U[word_to_id['woman']])}")
print(f"similarity between man and table : {cosine_similarity(U[word_to_id['man']],U[word_to_id['table']])}")
print(f"similarity between man and tree : {cosine_similarity(U[word_to_id['man']],U[word_to_id['tree']])}")
print(f"similarity between man and tree : {cosine_similarity(U[word_to_id['man']],U[word_to_id['tree']])}")
print(f"similarity between investment and portfolio : {cosine_similarity(U[word_to_id['investment']],U[word_to_id['portfolio']])}")
print(f"similarity between investment and drink : {cosine_similarity(U[word_to_id['investment']],U[word_to_id['drink']])}")
# Out:
# similarity between car and drive : 0.25078192353248596
# similarity between car and the : 0.08148854970932007
# similarity between car and street : -0.11724572628736496
# similarity between man and woman : 0.5597501993179321
# similarity between man and table : 0.22414074838161469
# similarity between man and tree : -0.07137893885374069
# similarity between man and tree : -0.07137893885374069
# similarity between investment and portfolio : 0.4311946630477905
# similarity between investment and drink : -0.02336348220705986

# %%
def most_similar(word, U:np.ndarray, word_to_id:dict, id_to_word:dict, n:int=100):
    if word not in word_to_id:
        raise Exception(f"{word} is not in the vocabulary")
    similarities = np.array([cosine_similarity(U[word_to_id[word]],word_rep) for i,word_rep in enumerate(U) if i!=word_to_id[word]])
    most_similar_word_ids = np.argsort(-1*similarities)
    for i in range(n):
        print(f"{i} :{id_to_word[most_similar_word_ids[i]]} (score : {similarities[most_similar_word_ids[i]]:.3f})")
    return most_similar_word_ids[:n]

# %%
ret = most_similar("cycle", U, word_to_id, id_to_word, n=10)
# Out:
# 0 :machine (score : 0.463)
# 1 :boom (score : 0.451)
# 2 :carpet (score : 0.425)
# 3 :steering (score : 0.415)
# 4 :sister (score : 0.414)
# 5 :woes (score : 0.406)
# 6 :alley (score : 0.398)
# 7 :tremendous (score : 0.395)
# 8 :fiber (score : 0.393)
# 9 :rhetoric (score : 0.393)
