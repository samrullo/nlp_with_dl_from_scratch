# %%
import pathlib
import numpy as np
import re
from sklearn.utils.extmath import randomized_svd
from utils import tokenize, build_vocabulary, get_word_to_id_from_vocab, get_id_to_word, build_corpus, create_cooccurrence_matrix

# %%
datasets_folder=pathlib.Path(r"C:\Users\amrul\programming\deep_learning\dl_projects\nlp_with_dl_from_scratch\datasets")
ptb_filename="ptb.train.txt"
text = (datasets_folder/ptb_filename).read_text()

# %%
words = tokenize(text,special_words=["<unk>"])
print(f"total of {len(words):,} words")
# Out:
# total of 937,128 words

# %%
vocab = build_vocabulary(words)
print(f"vocab has {len(vocab):,} words")
# Out:
# vocab has 9,654 words

# %%
word_to_id = get_word_to_id_from_vocab(list(vocab))
print(word_to_id)
# Out:
# {'influential': 0, 'disorders': 1, 'crossed': 2, 'local': 3, '$': 4, 'lights': 5, 'malignant': 6, 'bear': 7, 'opening': 8, 'video': 9, 'cope': 10, 'follows': 11, 'sept': 12, 'directly': 13, 'reaching': 14, 'george': 15, 'transport': 16, 'outstanding': 17, 'celebrity': 18, 'accomplished': 19, 'ceiling': 20, 'relies': 21, 'recently': 22, 'flag': 23, 'president': 24, 'realistic': 25, 'secret': 26, 'hopkins': 27, 'wheels': 28, 'officially': 29, 'slashed': 30, 'dealer': 31, 'chrysler': 32, 'crown': 33, 'crucial': 34, 'secondary': 35, 'civilian': 36, 'demanded': 37, 'cos': 38, 'wildly': 39, 'sagging': 40, 'connaught': 41, 'rig': 42, 'wednesday': 43, 'leslie': 44, 'contracts': 45, 'sour': 46, 'exploit': 47, 'surrendered': 48, 'avoid': 49, 'dominate': 50, 'vaccine': 51, 'cutbacks': 52, 'existence': 53, 'unraveled': 54, 'board': 55, 'fort': 56, 'asia': 57, 'sick': 58, 'burnham': 59, 'south': 60, 'reading': 61, 'thin': 62, 'afloat': 63, 'laser': 64, 'answers': 65, 'uninsured': 66, 'doctors': 67, 'brewery': 68, 'snack': 69, 'alarm': 70, 'type': 71, 'buffet': 72, 'weaken': 73, 'trade': 74, 'scheduled': 75, 'ai': 76, 'shift': 77, 'erosion': 78, 'skiing': 79, 'richmond': 80, 'uncovered': 81, 'judging': 82, 'beam': 83, 'technically': 84, 'sells': 85, 'potato': 86, 'spend': 87, 'us': 88, 'everyday': 89, 'adds': 90, 'appear': 91, 'measure': 92, 'reductions': 93, 'reactions': 94, 'bets': 95, 'necessarily': 96, 'book': 97, 'full': 98, 'tisch': 99, 'andrew': 100, 'disclose': 101, 'deserves': 102, 'strapped': 103, 'season': 104, 'mandate': 105, 'neil': 106, 'and': 107, 'oct': 108, 'likelihood': 109, 'irrelevant': 110, 'female': 111, 'buried': 112, 'p': 113, 'unfairly': 114, 'amsterdam': 115, 'warning': 116, 'g': 117, 'investigator': 118, 'birthday': 119, 'issuers': 120, 'carries': 121, 'embarrassing': 122, 'disrupted': 123, 'systems': 124, 'moore': 125, 'network': 126, 'somehow': 127, 'banxquote': 128, 'mcnamee': 129, 'foods': 130, 'elizabeth': 131, 'exchange': 132, 'weekes': 133, 'ifi': 134, 'magna': 135, 'schwartz': 136, 'paintings': 137, 'socialism': 138, 'marc': 139, 'uniform': 140, 'plumbing': 141, 'momentum': 142, 'drives': 143, 'vision': 144, 'diplomat': 145, 'will': 146, 'artistic': 147, 'output': 148, 'influence': 149, 'guerrillas': 150, 'aboard': 151, 'suitors': 152, 'undermine': 153, 'koch': 154, 'bruno': 155, 'reviewing': 156, 'instance': 157, 'known': 158, 'or': 159, 'bias': 160, 'direct': 161, 'hedges': 162, 'emerged': 163, 'expects': 164, 'valid': 165, 'overhaul': 166, 'participant': 167, 'deferring': 168, 'space': 169, 'besides': 170, 'jetliner': 171, 'knowledgeable': 172, 'rows': 173, 'historical': 174, 'knock': 175, 'witness': 176, 'technologies': 177, 'coaster': 178, 'funny': 179, 'nagging': 180, 'enemy': 181, 'filing': 182, 'hangs': 183, 'somewhat': 184, 'rebuilding': 185, 'gould': 186, 'ever': 187, 'younger': 188, 'renewed': 189, 'exempt': 190, 'confined': 191, 'leads': 192, 'southwest': 193, 'mentioned': 194, 'communists': 195, 'morrison': 196, '40': 197, 'fare': 198, 'dillon': 199, 'premier': 200, 'catholic': 201, 'gray': 202, 'mcalpine': 203, 'warned': 204, 'emissions': 205, 'internal': 206, 'targets': 207, 'rape': 208, 'executives': 209, 'costs': 210, 'favor': 211, 'spirits': 212, 'waves': 213, 'troubles': 214, 'uncomfortable': 215, 'costing': 216, 'chancellor': 217, 'manitoba': 218, 'entity': 219, 'beneficiaries': 220, 'clash': 221, 'china': 222, 'nora': 223, 'promptly': 224, 'swiftly': 225, 'deflator': 226, 'industry': 227, 'knew': 228, 'backs': 229, 'flexibility': 230, 'exterior': 231, 'mitterrand': 232, 'sponsors': 233, 'front': 234, 'thomson': 235, 'cautioned': 236, 'goodman': 237, 'coin': 238, 'setting': 239, 'spun': 240, 'transplants': 241, 'mccall': 242, 'enhanced': 243, 'patterns': 244, 'preparing': 245, 'leisure': 246, 'forward': 247, 'hole': 248, 'documents': 249, 'mesa': 250, 'facts': 251, 'kim': 252, 'columnist': 253, 'afternoon': 254, 're': 255, 'authorization': 256, 'milan': 257, 'exclusion': 258, 'constrain ...

# %%
id_to_word=get_id_to_word(word_to_id)
print(id_to_word)
# Out:
# {0: 'influential', 1: 'disorders', 2: 'crossed', 3: 'local', 4: '$', 5: 'lights', 6: 'malignant', 7: 'bear', 8: 'opening', 9: 'video', 10: 'cope', 11: 'follows', 12: 'sept', 13: 'directly', 14: 'reaching', 15: 'george', 16: 'transport', 17: 'outstanding', 18: 'celebrity', 19: 'accomplished', 20: 'ceiling', 21: 'relies', 22: 'recently', 23: 'flag', 24: 'president', 25: 'realistic', 26: 'secret', 27: 'hopkins', 28: 'wheels', 29: 'officially', 30: 'slashed', 31: 'dealer', 32: 'chrysler', 33: 'crown', 34: 'crucial', 35: 'secondary', 36: 'civilian', 37: 'demanded', 38: 'cos', 39: 'wildly', 40: 'sagging', 41: 'connaught', 42: 'rig', 43: 'wednesday', 44: 'leslie', 45: 'contracts', 46: 'sour', 47: 'exploit', 48: 'surrendered', 49: 'avoid', 50: 'dominate', 51: 'vaccine', 52: 'cutbacks', 53: 'existence', 54: 'unraveled', 55: 'board', 56: 'fort', 57: 'asia', 58: 'sick', 59: 'burnham', 60: 'south', 61: 'reading', 62: 'thin', 63: 'afloat', 64: 'laser', 65: 'answers', 66: 'uninsured', 67: 'doctors', 68: 'brewery', 69: 'snack', 70: 'alarm', 71: 'type', 72: 'buffet', 73: 'weaken', 74: 'trade', 75: 'scheduled', 76: 'ai', 77: 'shift', 78: 'erosion', 79: 'skiing', 80: 'richmond', 81: 'uncovered', 82: 'judging', 83: 'beam', 84: 'technically', 85: 'sells', 86: 'potato', 87: 'spend', 88: 'us', 89: 'everyday', 90: 'adds', 91: 'appear', 92: 'measure', 93: 'reductions', 94: 'reactions', 95: 'bets', 96: 'necessarily', 97: 'book', 98: 'full', 99: 'tisch', 100: 'andrew', 101: 'disclose', 102: 'deserves', 103: 'strapped', 104: 'season', 105: 'mandate', 106: 'neil', 107: 'and', 108: 'oct', 109: 'likelihood', 110: 'irrelevant', 111: 'female', 112: 'buried', 113: 'p', 114: 'unfairly', 115: 'amsterdam', 116: 'warning', 117: 'g', 118: 'investigator', 119: 'birthday', 120: 'issuers', 121: 'carries', 122: 'embarrassing', 123: 'disrupted', 124: 'systems', 125: 'moore', 126: 'network', 127: 'somehow', 128: 'banxquote', 129: 'mcnamee', 130: 'foods', 131: 'elizabeth', 132: 'exchange', 133: 'weekes', 134: 'ifi', 135: 'magna', 136: 'schwartz', 137: 'paintings', 138: 'socialism', 139: 'marc', 140: 'uniform', 141: 'plumbing', 142: 'momentum', 143: 'drives', 144: 'vision', 145: 'diplomat', 146: 'will', 147: 'artistic', 148: 'output', 149: 'influence', 150: 'guerrillas', 151: 'aboard', 152: 'suitors', 153: 'undermine', 154: 'koch', 155: 'bruno', 156: 'reviewing', 157: 'instance', 158: 'known', 159: 'or', 160: 'bias', 161: 'direct', 162: 'hedges', 163: 'emerged', 164: 'expects', 165: 'valid', 166: 'overhaul', 167: 'participant', 168: 'deferring', 169: 'space', 170: 'besides', 171: 'jetliner', 172: 'knowledgeable', 173: 'rows', 174: 'historical', 175: 'knock', 176: 'witness', 177: 'technologies', 178: 'coaster', 179: 'funny', 180: 'nagging', 181: 'enemy', 182: 'filing', 183: 'hangs', 184: 'somewhat', 185: 'rebuilding', 186: 'gould', 187: 'ever', 188: 'younger', 189: 'renewed', 190: 'exempt', 191: 'confined', 192: 'leads', 193: 'southwest', 194: 'mentioned', 195: 'communists', 196: 'morrison', 197: '40', 198: 'fare', 199: 'dillon', 200: 'premier', 201: 'catholic', 202: 'gray', 203: 'mcalpine', 204: 'warned', 205: 'emissions', 206: 'internal', 207: 'targets', 208: 'rape', 209: 'executives', 210: 'costs', 211: 'favor', 212: 'spirits', 213: 'waves', 214: 'troubles', 215: 'uncomfortable', 216: 'costing', 217: 'chancellor', 218: 'manitoba', 219: 'entity', 220: 'beneficiaries', 221: 'clash', 222: 'china', 223: 'nora', 224: 'promptly', 225: 'swiftly', 226: 'deflator', 227: 'industry', 228: 'knew', 229: 'backs', 230: 'flexibility', 231: 'exterior', 232: 'mitterrand', 233: 'sponsors', 234: 'front', 235: 'thomson', 236: 'cautioned', 237: 'goodman', 238: 'coin', 239: 'setting', 240: 'spun', 241: 'transplants', 242: 'mccall', 243: 'enhanced', 244: 'patterns', 245: 'preparing', 246: 'leisure', 247: 'forward', 248: 'hole', 249: 'documents', 250: 'mesa', 251: 'facts', 252: 'kim', 253: 'columnist', 254: 'afternoon', 255: 're', 256: 'authorization', 257: 'milan', 258: 'exclusion', 259: 'cons ...

# %%
corpus=build_corpus(words,word_to_id)
print(corpus[:100])
# Out:
# [3419, 1093, 5526, 8124, 6361, 2399, 6283, 6234, 4586, 7233, 3949, 9190, 1083, 7602, 5638, 8060, 2870, 8174, 2028, 9184, 5169, 885, 69, 3949, 2306, 1302, 1763, 1596, 6120, 4941, 2667, 3320, 2349, 146, 4506, 5297, 55, 6519, 6529, 655, 9428, 4441, 4043, 2667, 6757, 4043, 4941, 3241, 5669, 1061, 4941, 280, 4043, 786, 4043, 5297, 9538, 324, 5723, 1727, 4941, 2667, 3320, 2349, 107, 8707, 5669, 1061, 2358, 6576, 8427, 9556, 828, 7621, 6529, 655, 9428, 1061, 3155, 1900, 3710, 2568, 6529, 7738, 1061, 9230, 6495, 5841, 7528, 9050, 5920, 7824, 736, 3514, 3738, 6529, 5560, 7795, 1061, 9482]

# %%
C = create_cooccurrence_matrix(corpus,window_size=1,vocab_size=len(vocab))
print(f"cooccurrence shape :  {C.shape}")
# Out:
# cooccurrence shape :  (9654, 9654)

# %%
from utils import build_ppmi

ppmi = build_ppmi(C)

print(f"ppmi shape : {ppmi.shape}")
# Out:
# PPMI building: 100%|██████████| 93199716/93199716 [03:00<00:00, 515136.68it/s]
# ppmi shape : (9654, 9654)

# %%
U,S,V = randomized_svd(ppmi,n_components=100, n_iter= 5, random_state=None)

# %%
def cosine_similarity(u,v):
    return u@v/(np.linalg.norm(u)*np.linalg.norm(v))

# %%
print(f"similarity between car and drive : {cosine_similarity(U[word_to_id['car']],U[word_to_id['drive']])}")
print(f"similarity between car and the : {cosine_similarity(U[word_to_id['car']],U[word_to_id['the']])}")
print(f"similarity between car and street : {cosine_similarity(U[word_to_id['car']],U[word_to_id['street']])}")
print(f"similarity between man and woman : {cosine_similarity(U[word_to_id['man']],U[word_to_id['woman']])}")
print(f"similarity between man and table : {cosine_similarity(U[word_to_id['man']],U[word_to_id['table']])}")
print(f"similarity between man and tree : {cosine_similarity(U[word_to_id['man']],U[word_to_id['tree']])}")
print(f"similarity between man and tree : {cosine_similarity(U[word_to_id['man']],U[word_to_id['tree']])}")
print(f"similarity between investment and portfolio : {cosine_similarity(U[word_to_id['investment']],U[word_to_id['portfolio']])}")
print(f"similarity between investment and drink : {cosine_similarity(U[word_to_id['investment']],U[word_to_id['drink']])}")
# Out:
# similarity between car and drive : 0.3246625065803528
# similarity between car and the : 0.08762232959270477
# similarity between car and street : -0.08179930597543716
# similarity between man and woman : 0.5836743712425232
# similarity between man and table : 0.2704184651374817
# similarity between man and tree : -0.08587023615837097
# similarity between man and tree : -0.08587023615837097
# similarity between investment and portfolio : 0.4323898255825043
# similarity between investment and drink : 0.09997933357954025

# %%
def most_similar(word, U:np.ndarray, word_to_id:dict, id_to_word:dict, n:int=100):
    if word not in word_to_id:
        raise Exception(f"{word} is not in the vocabulary")
    similarities = np.array([cosine_similarity(U[word_to_id[word]],word_rep) for i,word_rep in enumerate(U) if i!=word_to_id[word]])
    most_similar_word_ids = np.argsort(-1*similarities)
    for i in range(n):
        print(f"{i} :{id_to_word[most_similar_word_ids[i]]} (score : {similarities[most_similar_word_ids[i]]:.3f})")
    return most_similar_word_ids[:n]

# %%
ret = most_similar("auto", U, word_to_id, id_to_word, n=10)
# Out:
# 0 :pharmaceutical (score : 0.699)
# 1 :developing (score : 0.684)
# 2 :redeemed (score : 0.671)
# 3 :fate (score : 0.643)
# 4 :withheld (score : 0.607)
# 5 :fee (score : 0.606)
# 6 :dismissed (score : 0.600)
# 7 :bitterly (score : 0.580)
# 8 :refunding (score : 0.580)
# 9 :airline (score : 0.579)
